# %%
from google.colab import drive
drive.mount('/content/gdrive/')

##https://drive.google.com/file/d/1gBPKIItfis78kqiG5t78hEVPkBIhQPum/view?usp=sharing
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd
import spacy

nlp = spacy.load("en")

# %%
df=pd.read_csv('gdrive/My Drive/MIDS/NLP_w266/w266_Final_Project/Data/transcript_1.csv')

# %%
def define_vocab(lst):
  ls_spt = []

  for elem in ls:
    elem = elem.replace('[','')
    elem = elem.replace(']','')
    elem = elem.replace('\r\n','')
    ls_spt.append(elem.split(' '))

  ls_spt = [item for items in ls_spt for item in items]
  ls_spt = list(set(ls_sp
  retur

# %%
df_all = df.loc[:, ['transcriptid', 'componentorder', 'transcriptcomponenttypeid','componenttext','transcriptpersonid']].sort_values(['transcriptid','componentorder'])
df_all = df_all.dropna(subset=['componenttext'])
ls = list(df_all['componenttext'][:500000])
#print(len(ls)) --1166173

ls_new = define_vocab(ls)
print(len(ls_new))
# Out:
# 432286

# %%
ls_new[:25]

# %%
#transcriptcomponenttypeid
#1	Presentation Operator Message
#2	Presenter Speech
#3	Question
#4	Answer
#5	Presentation Section
#6	Question And Answer Section
#7	Question and Answer Operator Message
#8	Unknown Question and Answer Message

#if scope == 'PR':
#  df = transcript[transcript.transcriptcomponenttypeid.isin([1,2,5,7])]
#elif scope == 'QA':
#  df = transcript[transcript.transcriptcomponenttypeid.isin([3,4,6,8])]

# %%
df2 = df[(df['transcriptcomponenttypeid']==8)].sort_values(['transcriptid','componentorder'])

list(df2['componenttext'])

# %%
myfile = open("gdrive/My Drive/MIDS/NLP_w266/w266_Final_Project/Data/transcript_1.csv")
data = myfile.readlines()

# %%
len(data)

# %%
for sentence in data[:200]:
  sent = sentence.split(',')
  if len(sent) > 6:
    print(sent)
    print(len(sent))

# %%
import tensorflow as tf

alb_file = "gdrive/My Drive/MIDS/NLP_w266/w266_Final_Project/Data/Others/finBert_pretrain.tfrecord"
raw_dataset = tf.data.TFRecordDataset(alb_file)
raw_dataset
# Out:
# <TFRecordDatasetV2 shapes: (), types: tf.string>

# %%
for raw_record in raw_dataset.take(1):
  example = tf.train.Example()
  example.ParseFromString(raw_record.numpy())
  print(example)
# Out:
# features {
#   feature {
#     key: "input_ids"
#     value {
#       int64_list {
#         value: 2
#         value: 46
#         value: 12
#         value: 239
#         value: 4
#         value: 4
#         value: 1
#         value: 1017
#         value: 566
#         value: 4
#         value: 36
#         value: 363
#         value: 21
#         value: 1989
#         value: 27
#         value: 3628
#         value: 133
#         value: 1
#         value: 46
#         value: 6
#         value: 987
#         value: 27
#         value: 15
#         value: 3133
#         value: 1882
#         value: 4
#         value: 4
#         value: 4
#         value: 12852
#         value: 589
#         value: 17
#         value: 3628
#         value: 133
#         value: 40
#         value: 17
#         value: 11120
#         value: 133
#         value: 11
#         value: 24262
#         value: 5
#         value: 1
#         value: 49
#         value: 17
#         value: 1
#         value: 1
# ...
